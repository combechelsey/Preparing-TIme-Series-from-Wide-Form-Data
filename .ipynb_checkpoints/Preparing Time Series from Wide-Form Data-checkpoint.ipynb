# %% [markdown]
# You will be working with Zillow's publicly available Zillow House Value Index (ZHVI) https://www.zillow.com/research/data/
#
# - Specifically, you will be using the Home Value data set for:
#     - Data Type = "ZHVI All Homes (SFR+Condo/Coop) - Time Series - Smoothed - Seasonally Adjusted"
#     - Geography = "City"
# - We have already downloaded the file for you and uploaded it to Google Drive.
#     - Share URL: https://drive.google.com/file/d/1O_g44QAfe3uVF-1heAC0BAeVDoWloVR-/view?usp=sharing
#     - Direct URL (for Pandas): https://docs.google.com/spreadsheets/d/e/2PACX-1vQN3Ksa9szQuO4G1-msXWAp17KtVHQCBnuEieu_auu1wSiBf3-krHusIx5VBMkihxj-KZLBosDIGEyR/pub?output=csv

# %% [markdown]
# # Part 1
#
# - First, you will prepare the dataset for time series analysis:
#     - Load in the Zillow Home Value Index dataframe.
#         - Note: it is a large file and may take a minute to load.

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import os
# set random seed
SEED = 321
np.random.seed(SEED)

## Customization Options
# plt.style.use(['fivethirtyeight'])#'seaborn-talk'])#,
plt.rcParams['figure.facecolor']='white'
plt.rcParams['figure.figsize']=(12,4)
#import tick customization tools
import matplotlib.ticker as mticks
import matplotlib.dates as mdates
sns.set_context("talk", font_scale=0.9)

def format_xdates(ax, fig=None, xtick_fontweight='bold',
               title= None):
    """Formats x-axis with minor ticks every 3 months, and major 
    ticks every year. Includes different grid options for visibility"""
    # create the locator to place ticks every 3 months.
    loc_3months = mdates.MonthLocator(interval=3)
    fmt_months = mdates.DateFormatter("%b")
    ## for major year ticks
    loc_year = mdates.YearLocator()
    fmt_year = mdates.DateFormatter("%Y")
    
    ## Change the font of the major ticks to stand out
    ax.set_xticks(ax.get_xticks())
    ax.set_xticklabels(ax.get_xticklabels(), 
                       fontweight=xtick_fontweight) 
    
    ## customize minor ticks
    ax.xaxis.set_minor_locator(loc_3months)
    ax.xaxis.set_minor_formatter(fmt_months)
    ## customize major ticks
    ax.xaxis.set_major_locator(loc_year)
    ax.xaxis.set_major_formatter(fmt_year)
    ## Making major/minor gridlines visually distince
    ax.grid(which='minor',axis='x',ls=":")
    ax.grid(which='major',axis='x',color='k')
    if fig is None:
        fig = ax.get_figure()
    ## rotate the dates
    fig.autofmt_xdate(which='major',rotation=90,ha='center')
    return fig,ax

# %%
# Load Data
url = "https://docs.google.com/spreadsheets/d/e/2PACX-1vQN3Ksa9szQuO4G1-msXWAp17KtVHQCBnuEieu_auu1wSiBf3-krHusIx5VBMkihxj-KZLBosDIGEyR/pub?output=csv"
df = pd.read_csv(url)
df
# Out:
#        RegionID  SizeRank      RegionName RegionType StateName State  \
# 0          6181         0        New York       city        NY    NY
# 1         12447         1     Los Angeles       city        CA    CA
# 2         39051         2         Houston       city        TX    TX
# 3         17426         3         Chicago       city        IL    IL
# 4          6915         4     San Antonio       city        TX    TX
# ...         ...       ...             ...        ...       ...   ...
# 22462    236350     28439       Palisades       city        TX    TX
# 22463     40403     28439  Port Mansfield       city        TX    TX
# 22464     54740     28439     Tribes Hill       city        NY    NY
# 22465    249186     28439    Derby Center       city        VT    VT
# 22466     42575     28439        Quinwood       city        WV    WV
#
#                                        Metro          CountyName  2000-01-31  \
# ...

# %% [markdown]
# - Filter the 4 largest cities into a new dataframe.
#
#     - Tip: the "SizeRank" column has already ranked the cities by size. The larger the city, the smaller the rank value.
#         - Therefore the 4 largest cities would have rank values of [0,1,2,3]

# %%
# Filter for size rank < 4
df = df[df['SizeRank']<4]

# %%
# Checking that filter was applied correctly
df["SizeRank"].value_counts()
# Out:
# SizeRank
# 0    1
# 1    1
# 2    1
# 3    1
# Name: count, dtype: int64

# %% [markdown]
# - Melt the data to long-form and prepare it for time series analysis.
#
#     - Convert the melted dates into datetime datatype.
#     - Make the datetime column the index.

# %%
# Combine date columns
melted = pd.melt(df, id_vars=['RegionID', 'SizeRank', 'RegionName', 'RegionType', 'StateName', 'State', 'Metro', 'CountyName'], var_name="Date")
melted
# Out:
#       RegionID  SizeRank   RegionName RegionType StateName State  \
# 0         6181         0     New York       city        NY    NY
# 1        12447         1  Los Angeles       city        CA    CA
# 2        39051         2      Houston       city        TX    TX
# 3        17426         3      Chicago       city        IL    IL
# 4         6181         0     New York       city        NY    NY
# ...        ...       ...          ...        ...       ...   ...
# 1087     17426         3      Chicago       city        IL    IL
# 1088      6181         0     New York       city        NY    NY
# 1089     12447         1  Los Angeles       city        CA    CA
# 1090     39051         2      Houston       city        TX    TX
# 1091     17426         3      Chicago       city        IL    IL
#
#                                       Metro          CountyName        Date  \
# 0     New York-Newark-Jersey City, NY-NJ-PA       Queens County  2000-01-31
# ...

# %%
# Changing date column to datetime type
melted['Date'] = pd.to_datetime(melted['Date'])

# %%
# Setting Date as column index
melted = melted.set_index("Date")

# %%
# Viewing Dataframe 
melted
# Out:
#             RegionID  SizeRank   RegionName RegionType StateName State  \
# Date
# 2000-01-31      6181         0     New York       city        NY    NY
# 2000-01-31     12447         1  Los Angeles       city        CA    CA
# 2000-01-31     39051         2      Houston       city        TX    TX
# 2000-01-31     17426         3      Chicago       city        IL    IL
# 2000-02-29      6181         0     New York       city        NY    NY
# ...              ...       ...          ...        ...       ...   ...
# 2022-08-31     17426         3      Chicago       city        IL    IL
# 2022-09-30      6181         0     New York       city        NY    NY
# 2022-09-30     12447         1  Los Angeles       city        CA    CA
# 2022-09-30     39051         2      Houston       city        TX    TX
# 2022-09-30     17426         3      Chicago       city        IL    IL
#
#                                             Metro          CountyName  \
# Date
# ...

# %% [markdown]
# - Resample the dataframe as monthly frequency, grouped by City.

# %%
# Resample as monthly frequency grouped by city
city_month = melted.groupby('RegionName').resample("M").sum()
city_month
# Out:
#                        RegionID  SizeRank RegionName RegionType StateName  \
# RegionName Date
# Chicago    2000-01-31     17426         3    Chicago       city        IL
#            2000-02-29     17426         3    Chicago       city        IL
#            2000-03-31     17426         3    Chicago       city        IL
#            2000-04-30     17426         3    Chicago       city        IL
#            2000-05-31     17426         3    Chicago       city        IL
# ...                         ...       ...        ...        ...       ...
# New York   2022-05-31      6181         0   New York       city        NY
#            2022-06-30      6181         0   New York       city        NY
#            2022-07-31      6181         0   New York       city        NY
#            2022-08-31      6181         0   New York       city        NY
#            2022-09-30      6181         0   New York       city        NY
#
# ...

# %% [markdown]
# # Part 2
#
# - Once you've prepared the dataframe with the time series data for the 4 largest cities:
#     - Plot the home values for all 4 cities. (Hint: use unstack)
#         - Make sure to add a title and axis labels.
#         - Reformat the y-axis ticks to use thousands of dollars with a "K" at the end. (e.g. "200K, 400K, etc")
#             - Hint: use the FuncFormatter from matplotlib

# %%
# level 0 is RegionName
city_month.index.get_level_values(0)
# Out:
# Index(['Chicago', 'Chicago', 'Chicago', 'Chicago', 'Chicago', 'Chicago',
#        'Chicago', 'Chicago', 'Chicago', 'Chicago',
#        ...
#        'New York', 'New York', 'New York', 'New York', 'New York', 'New York',
#        'New York', 'New York', 'New York', 'New York'],
#       dtype='object', name='RegionName', length=1092)

# %%
# level 1 is Date
city_month.index.get_level_values(1)
# Out:
# DatetimeIndex(['2000-01-31', '2000-02-29', '2000-03-31', '2000-04-30',
#                '2000-05-31', '2000-06-30', '2000-07-31', '2000-08-31',
#                '2000-09-30', '2000-10-31',
#                ...
#                '2021-12-31', '2022-01-31', '2022-02-28', '2022-03-31',
#                '2022-04-30', '2022-05-31', '2022-06-30', '2022-07-31',
#                '2022-08-31', '2022-09-30'],
#               dtype='datetime64[ns]', name='Date', length=1092, freq=None)

# %%
unstacked = city_month.unstack(level=0)
unstacked
# Out:
#            RegionID                              SizeRank                      \
# RegionName  Chicago Houston Los Angeles New York  Chicago Houston Los Angeles
# Date
# 2000-01-31    17426   39051       12447     6181        3       2           1
# 2000-02-29    17426   39051       12447     6181        3       2           1
# 2000-03-31    17426   39051       12447     6181        3       2           1
# 2000-04-30    17426   39051       12447     6181        3       2           1
# 2000-05-31    17426   39051       12447     6181        3       2           1
# ...             ...     ...         ...      ...      ...     ...         ...
# 2022-05-31    17426   39051       12447     6181        3       2           1
# 2022-06-30    17426   39051       12447     6181        3       2           1
# 2022-07-31    17426   39051       12447     6181        3       2           1
# 2022-08-31    17426   39051       12447     6181        3       2           1
# ...

# %%
value_trends = unstacked['value']

# %%
fig, ax = plt.subplots(figsize=(15,8))

# Set labels and title
ax.set_xlabel("Date")
ax.set_ylabel("Home Values ($)")
ax.set_title("Home Values Trends")

# create the locator to place ticks every 3 months.
loc_3months = mdates.MonthLocator(interval=3)
fmt_months = mdates.DateFormatter("%b")
## for major year ticks
YearLocator = mdates.YearLocator()
fmt_year = mdates.DateFormatter("%Y")

# Customize the major x-axis ticks
loc_year = mdates.YearLocator(base=1)  # Major ticks every 1 year
fmt_year = mdates.DateFormatter('%Y')  # Format as 4-digit years

## customize major ticks
ax.xaxis.set_major_locator(loc_year)
ax.xaxis.set_major_formatter(fmt_year)

## customize minor ticks
ax.xaxis.set_minor_locator(loc_3months)
ax.xaxis.set_minor_formatter(fmt_months)

## Making major/minor gridlines visually distinct
ax.grid(which='minor',axis='x',ls=":")
ax.grid(which='major',axis='x',color='k')
fig.autofmt_xdate(rotation=90 ,ha='center')

ax.plot(value_trends.index, value_trends)

# Remove the labels for minor ticks
ax.tick_params(axis='x', which='minor', labelbottom=False)
ax.legend(value_trends)


# Show the plot
plt.tight_layout()
plt.show();

# %% [markdown]
# - Answer the following 2 questions using pandas:
#
#    -  1) Which City had the highest Typical Home Value at the end of 2008? Which had the least?
#         - Hint: You can use the unstacked dataframe or use pd.IndexSlice with the multiindex.

# %%
# Filter for end of 2008 data
end_of_2008_data = city_month.loc[pd.IndexSlice[:, '2008-12-31'], :]

# %%
# Find the city with the highest home value at end of 2008
highest_value_city = end_of_2008_data['value'].idxmax()[0]
print(f'The city with the highest home values at the end of 2008 was {highest_value_city}.')
# Out:
# The city with the highest home values at the end of 2008 was New York.

# %%
# Find the city with the highest home value at end of 2008
lowest_value_city = end_of_2008_data['value'].idxmin()[0]
print(f'The city with the least home values at the end of 2008 was {lowest_value_city}.')
# Out:
# The city with the least home values at the end of 2008 was Houston.

# %% [markdown]
# - 2) How much did the home values change from November 2008 to December 2008 (in dollars)?
#
#     - Hint: you can use .diff() to calculate the change in values

# %%
# Resample melted for average value in both months?

# %%
# Viewing Dataframe 
melted
# Out:
#             RegionID  SizeRank   RegionName RegionType StateName State  \
# Date
# 2000-01-31      6181         0     New York       city        NY    NY
# 2000-01-31     12447         1  Los Angeles       city        CA    CA
# 2000-01-31     39051         2      Houston       city        TX    TX
# 2000-01-31     17426         3      Chicago       city        IL    IL
# 2000-02-29      6181         0     New York       city        NY    NY
# ...              ...       ...          ...        ...       ...   ...
# 2022-08-31     17426         3      Chicago       city        IL    IL
# 2022-09-30      6181         0     New York       city        NY    NY
# 2022-09-30     12447         1  Los Angeles       city        CA    CA
# 2022-09-30     39051         2      Houston       city        TX    TX
# 2022-09-30     17426         3      Chicago       city        IL    IL
#
#                                             Metro          CountyName  \
# Date
# ...

# %%
# Resample as monthly frequency grouped by city
city_month_ave = melted.groupby('RegionName')['value'].resample("M").mean()
city_month_ave
# Out:
# RegionName  Date
# Chicago     2000-01-31    166139.0
#             2000-02-29    166536.0
#             2000-03-31    167368.0
#             2000-04-30    168826.0
#             2000-05-31    170499.0
#                             ...
# New York    2022-05-31    768797.0
#             2022-06-30    773944.0
#             2022-07-31    777692.0
#             2022-08-31    779960.0
#             2022-09-30    781622.0
# Name: value, Length: 1092, dtype: float64

# %%
change = city_month_ave.diff()
change
# Out:
# RegionName  Date
# Chicago     2000-01-31       NaN
#             2000-02-29     397.0
#             2000-03-31     832.0
#             2000-04-30    1458.0
#             2000-05-31    1673.0
#                            ...
# New York    2022-05-31    6476.0
#             2022-06-30    5147.0
#             2022-07-31    3748.0
#             2022-08-31    2268.0
#             2022-09-30    1662.0
# Name: value, Length: 1092, dtype: float64

# %%
# Get a list of unique RegionName values
unique_regions = change['RegionName'].unique()

# Loop through each RegionName
for region_name in unique_regions:

    dec_2008_change = change[(change['RegionName'] == region_name) & (change['Date'] == '2008-12-31')]
    
    # Check if there is data for both November and December 2008
    if not (nov_2008_change.empty or dec_2008_change.empty):
        # Print the changes for the current region
        print(f"Change from November 2008 to December 2008: {dec_2008_change}")
        print()
# Out:
# Change from November 2008 to December 2008:     RegionName       Date   value
# 107    Chicago 2008-12-31 -5753.0
#
# Change from November 2008 to December 2008:     RegionName       Date  value
# 380    Houston 2008-12-31 -964.0
#
# Change from November 2008 to December 2008:       RegionName       Date    value
# 653  Los Angeles 2008-12-31 -12611.0
#
# Change from November 2008 to December 2008:     RegionName       Date   value
# 926   New York 2008-12-31 -4458.0

# %%
# Filter for November 2008 and December 2008 data
november_2008_data = city_month['value'].loc[pd.IndexSlice[:, '2008-11-30'], :]
december_2008_data = city_month['value'].loc[pd.IndexSlice[:, '2008-12-31'], :]

change = december_2008_data - november_2008_data

change
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Cell In [75], line 2
#       1 # Filter for November 2008 and December 2008 data
# ----> 2 november_2008_data = city_month['value'].loc[pd.IndexSlice[:, '2008-11-30'], :]
#       3 december_2008_data = city_month['value'].loc[pd.IndexSlice[:, '2008-12-31'], :]
#       5 change = december_2008_data - november_2008_data
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\indexing.py:1147, in _LocationIndexer.__getitem__(self, key)
#    1145     if self._is_scalar_access(key):
#    1146         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1147     return self._getitem_tuple(key)
#    1148 else:
#    1149     # we by definition only have the 0th axis
#    1150     axis = self.axis or 0
#
# ...
